# %%
# %pip install -U google-genai python-dotenv
# Out:
# Requirement already satisfied: google-genai in c:\users\shrey\appdata\local\programs\python\python312\lib\site-packages (2.23.0)
# Requirement already satisfied: python-dotenv in c:\users\shrey\appdata\local\programs\python\python312\lib\site-packages (1.2.3)
# Requirement already satisfied: anyio<5.0.0,>=4.8.0 in c:\users\shrey\appdata\local\programs\python\python312\lib\site-packages (from google-genai) (4.11.0)
# Requirement already satisfied: google-auth<3.0.0,>=2.56.0 in c:\users\shrey\appdata\local\programs\python\python312\lib\site-packages (from google-auth[requests]<3.0.0,>=2.56.0->google-genai) (2.58.0)
# Requirement already satisfied: httpx<1.0.0,>=0.28.1 in c:\users\shrey\appdata\local\programs\python\python312\lib\site-packages (from google-genai) (0.28.1)
# Requirement already satisfied: pydantic<3.0.0,>=2.12.5 in c:\users\shrey\appdata\local\programs\python\python312\lib\site-packages (from google-genai) (2.12.5)
# Requirement already satisfied: requests<3.0.0,>=2.28.1 in c:\users\shrey\appdata\local\programs\python\python312\lib\site-packages (from google-genai) (2.32.5)
# Requirement already satisfied: tenacity<9.2.0,>=8.2.3 in c:\users\shrey\appdata\local\programs\python\python312\lib\site-packages (from google-genai) (9.1.4)
# Requirement already satisfied: websockets<17.0,>=13.0.0 in c:\users\shrey\appdata\local\programs\python\python312\lib\site-packages (from google-genai) (16.1.1)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.14.0 in c:\users\shrey\appdata\local\programs\python\python312\lib\site-packages (from google-genai) (4.15.0)
# Requirement already satisfied: distro<2,>=1.7.0 in c:\users\shrey\appdata\local\programs\python\python312\lib\site-packages (from google-genai) (1.9.0)
# Requirement already satisfied: sniffio in c:\users\shrey\appdata\local\programs\python\python312\lib\site-packages (from google-genai) (1.3.1)
# Requirement already satisfied: idna>=2.8 in c:\users\shrey\appdata\local\programs\python\python312\lib\site-packages (from anyio<5.0.0,>=4.8.0->google-genai) (3.11)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\shrey\appdata\local\programs\python\python312\lib\site-packages (from google-auth<3.0.0,>=2.56.0->google-auth[requests]<3.0.0,>=2.56.0->google-genai) (0.4.2)
# Requirement already satisfied: cryptography>=38.0.3 in c:\users\shrey\appdata\local\programs\python\python312\lib\site-packages (from google-auth<3.0.0,>=2.56.0->google-auth[requests]<3.0.0,>=2.56.0->google-genai) (46.0.4)
# Requirement already satisfied: certifi in c:\users\shrey\appdata\local\programs\python\python312\lib\site-packages (from httpx<1.0.0,>=0.28.1->google-genai) (2025.10.5)
# Requirement already satisfied: httpcore==1.* in c:\users\shrey\appdata\local\programs\python\python312\lib\site-packages (from httpx<1.0.0,>=0.28.1->google-genai) (1.0.9)
# Requirement already satisfied: h11>=0.16 in c:\users\shrey\appdata\local\programs\python\python312\lib\site-packages (from httpcore==1.*->httpx<1.0.0,>=0.28.1->google-genai) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\shrey\appdata\local\programs\python\python312\lib\site-packages (from pydantic<3.0.0,>=2.12.5->google-genai) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.5 in c:\users\shrey\appdata\local\programs\python\python312\lib\site-packages (from pydantic<3.0.0,>=2.12.5->google-genai) (2.41.5)
# Requirement already satisfied: typing-inspection>=0.4.2 in c:\users\shrey\appdata\local\programs\python\python312\lib\site-packages (from pydantic<3.0.0,>=2.12.5->google-genai) (0.4.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\shrey\appdata\local\programs\python\python312\lib\site-packages (from requests<3.0.0,>=2.28.1->google-genai) (3.4.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\shrey\appdata\local\programs\python\python312\lib\site-packages (from requests<3.0.0,>=2.28.1->google-genai) (2.5.0)
# Requirement already satisfied: cffi>=2.0.0 in c:\users\shrey\appdata\local\programs\python\python312\lib\site-packages (from cryptography>=38.0.3->google-auth<3.0.0,>=2.56.0->google-auth[requests]<3.0.0,>=2.56.0->google-genai) (2.0.0)
# Requirement already satisfied: pycparser in c:\users\shrey\appdata\local\programs\python\python312\lib\site-packages (from cffi>=2.0.0->cryptography>=38.0.3->google-auth<3.0.0,>=2.56.0->google-auth[requests]<3.0.0,>=2.56.0->google-genai) (2.23)
# Requirement already satisfied: pyasn1<0.7.0,>=0.6.1 in c:\users\shrey\appdata\local\programs\python\python312\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth<3.0.0,>=2.56.0->google-auth[requests]<3.0.0,>=2.56.0->google-genai) (0.6.4)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.3 -> 26.2.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import os
from dotenv import load_dotenv
from google import genai

load_dotenv()

api_key = os.getenv("GEMINI_API_KEY")

if not api_key:
    raise ValueError("GEMINI_API_KEY not found in .env")

client = genai.Client(api_key=api_key)

response = client.models.generate_content(
    model="gemini-3.7-flash",
    contents="Explain what RAG is in one sentence."
)

print(response.text)
# Out:
# Direct use of automatic function calling (AFC) in Models.generate_content is not recommended. Instead, we recommend to use AFC in Chat.send_message. Similarly, direct use of AFC in Models.generate_content_stream is not recommended. Instead, we recommend to use AFC in Chat.send_message_stream.
# **Retrieval-Augmented Generation (RAG)** is an AI framework that enhances a language model's responses by retrieving relevant, up-to-date information from external knowledge bases before generating an answer.

# %%
response = client.models.generate_content(
    model="gemini-3.7-flash",
    contents="Do you know my name"
)

print(response.text)
# Out:
# No, I don't know your name. Since you haven't shared it with me yet, feel free to tell me what you'd like me to call you!
